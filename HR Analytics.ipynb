# %% [markdown]
# **NAME:- KONKAL KAILASH VENKATESH**
#
# **BATCH NO:- DS2312**
#
# **PROJECT:- HR ANALYTICS**

# %%
# import neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings # filter warnings
warnings.filterwarnings('ignore')

# %%
# import data
data = pd.read_csv(r"C:\Users\SHAILESH\Downloads\ibm-hr-analytics-employee-attrition-performance.zip")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
print('No. of rows',data.shape[0])
print('No. of columns',data.shape[1])
# Out:
# No. of rows 1470
# No. of columns 35

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# From the above Observation we can say that,
#
# * There are 1470 rows and 35 column out of which we have 9 features with object datatypes and 20 are int64 types.
# * Label is 'Attrition'.
# * There are No Null Values in our dataset.

# %% [markdown]
# ##### These Ordinal features come with following label encoding:-
#
# * Education: 1- Below College, 2- College, 3- Bachelor, 4- Masters, 5- Doctors.
# * EnvironmentSatisfaction: 1- Low, 2- Medium, 3- High, 4- Very High.
# * Jobinvolvement: 1- Low, 2- Medium, 3- High, 4- Very High.
# * JobSatisfaction:  1- Low, 2- Medium, 3- High, 4- Very High.
# * PerformanceRating: 1- Low, 2- Average, 3- Good, 4- Excellent, 5- Outstanding.
# * RelationshipSatisfaction: 1- Low, 2- Medium, 3- High, 4- Very High.
# * WorkLifeBalance: 1- Bad, 2- Good, 3- Better, 4- Best.
#
# # Statistical Analysis
#
# #### Data Integrity Check

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Dataset doesnot contains Any duplicate values so we can proceed further

# %% [markdown]
# #### Statistical Matrix

# %%
# visulaize the statistics of the columns using heatmap.

plt.figure(figsize=(28,10))
sns.heatmap(data.describe(),linewidths = 0.1, fmt='0.1f', annot = True, cmap='PiYG')
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.00
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StandardHours             1470.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %% [markdown]
# From the above observation we can say that,
#
# * Minimum employee age is 18 and maximum employee age is 60.
# * Average distance from home is 9.1KM. It's means that most of employees travel atleast 18 km in a day.
# * 50% of employees has 2 years of work experience previously.
# * For Monthly Income Monthly rate by looking at 50% and max columns we can say outliers exits in this features.
# * By looking at mean and median we can see that some of the features are skewed in nature.
#
# #### Let's start with some Statistical Analysis.

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
labels ='Yes', 'NO',
fig, ax= plt.subplots()
ax.pie(data['Attrition'].value_counts(),labels = labels, radius= 1, autopct= '%2.2f%%', explode=[0.1,0.2], shadow=True)
plt.show()

# %% [markdown]
# * 83.88%(1237 employees) Employees did not leave the organization while 16.12% (237 employees) left the organization.
# * Making our datasets to be considered imbalanced since more people stay in organisation compared to the employees who left.

# %%
Category = ['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']
for i in Category:
    print(i)
    print(data[i].value_counts())
    print("*"*100)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ****************************************************************************************************
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ****************************************************************************************************
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ****************************************************************************************************
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ****************************************************************************************************
# Gender
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ****************************************************************************************************
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# ****************************************************************************************************
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# ****************************************************************************************************
# Over18
# Y    1470
# Name: Over18, dtype: int64
# ****************************************************************************************************
# OverTime
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# ****************************************************************************************************

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20), facecolor ='white')
plotnumber = 1
Category = ['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']
for i in Category:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(x=i,data=data)
        plt.xlabel(i,fontsize = 20)
        plt.xticks(rotation = 30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### listing Value Counts & Sub-Categories of different Ordinal Features available

# %%
Oridinal = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','RelationshipSatisfaction','PerformanceRating','WorkLifeBalance']
for i in Oridinal:
    print(i)
    print(data[i].value_counts())
    print("*"*100)
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# ****************************************************************************************************
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
# ****************************************************************************************************
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# ****************************************************************************************************
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# ****************************************************************************************************
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64
# ****************************************************************************************************
# PerformanceRating
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64
# ****************************************************************************************************
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64
# ****************************************************************************************************

# %%
sns.set_palette('hsv')
plt.figure(figsize=(20,20), facecolor ='white')
plotnumber = 1
Oridinal = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','RelationshipSatisfaction','PerformanceRating','WorkLifeBalance']
for i in Oridinal:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(x=i,data=data)
        plt.xlabel(i,fontsize = 20)
        plt.xticks(rotation = 30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
labels ='Bachelor', 'Master','College','Below College','Doctor'
fig, ax= plt.subplots()
ax.pie(data['Education'].value_counts(),labels = labels, radius= 1, autopct= '%3.2f%%', explode=[0.1,0.1,0.15,0.2,0.3], shadow=True)
plt.show()

# %% [markdown]
# From the Above observation, we can say that
#
# * More than 60% employees have pursued bachelors and masters degree.
# * 30% of employees are highly educated with masters and doctor degree.
# * 39% of employees are graduated.
# * 19% of employees are have completed their college & 12% are below college.
#
# ### Let's try to gain insights on  which department this human resources belong and education need of each department through visulalization.

# %%
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
labels ='Research & Development','Sales','Human Resources'
fig, ax= plt.subplots()
ax.pie(data['Department'].value_counts(),labels = labels, radius= 1, autopct= '%3.2f%%', explode=[0.1,0.15,0.2], shadow=True)
plt.show()

# %%
pd.crosstab([data.Education],[data.Department], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ec485_row0_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_ec485_row0_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_ec485_row0_col2 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_ec485_row0_col3 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_ec485_row1_col0, #T_ec485_row1_col2, #T_ec485_row1_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_ec485_row1_col1 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_ec485_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_ec485_row2_col1 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_ec485_row2_col2 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_ec485_row2_col3 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_ec485_row3_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_ec485_row3_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_ec485_row3_col2 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_ec485_row3_col3 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_ec485_row4_col0, #T_ec485_row4_col1, #T_ec485_row4_col2, #T_ec485_row4_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ec485_row5_col0, #T_ec485_row5_col1, #T_ec485_row5_col2, #T_ec485_row5_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ec485">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_ec485_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_ec485_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_ec485_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_ec485_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec485_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ec485_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_ec485_row0_col1" class="data row0 col1" >115</td>
#       <td id="T_ec485_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_ec485_row0_col3" class="data row0 col3" >170</td>
#     </tr>
#     <tr>
#       <th id="T_ec485_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ec485_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_ec485_row1_col1" class="data row1 col1" >182</td>
#       <td id="T_ec485_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_ec485_row1_col3" class="data row1 col3" >282</td>
#     </tr>
#     <tr>
#       <th id="T_ec485_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ec485_row2_col0" class="data row2 col0" >27</td>
#       <td id="T_ec485_row2_col1" class="data row2 col1" >379</td>
#       <td id="T_ec485_row2_col2" class="data row2 col2" >166</td>
#       <td id="T_ec485_row2_col3" class="data row2 col3" >572</td>
#     </tr>
#     <tr>
#       <th id="T_ec485_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ec485_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_ec485_row3_col1" class="data row3 col1" >255</td>
#       <td id="T_ec485_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_ec485_row3_col3" class="data row3 col3" >398</td>
#     </tr>
#     <tr>
#       <th id="T_ec485_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ec485_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_ec485_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_ec485_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_ec485_row4_col3" class="data row4 col3" >48</td>
#     </tr>
#     <tr>
#       <th id="T_ec485_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_ec485_row5_col0" class="data row5 col0" >63</td>
#       <td id="T_ec485_row5_col1" class="data row5 col1" >961</td>
#       <td id="T_ec485_row5_col2" class="data row5 col2" >446</td>
#       <td id="T_ec485_row5_col3" class="data row5 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From the above observation we can say that,
#
# * 65.37% of employees belong to Research & Development Department.
# * Out of total 961 Employees no of employee educated at bachelors, Masters, Doctors are 379,225 and 30 respectively.
# *  Only 63 employee work in HR department.

# %%
pd.crosstab([data.Education],[data.Department,data.Attrition], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7987f_row0_col0 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_7987f_row0_col1, #T_7987f_row4_col0, #T_7987f_row4_col1, #T_7987f_row4_col2, #T_7987f_row4_col3, #T_7987f_row4_col4, #T_7987f_row4_col5, #T_7987f_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7987f_row0_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_7987f_row0_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_7987f_row0_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_7987f_row0_col5 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_7987f_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_7987f_row1_col0, #T_7987f_row1_col4 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_7987f_row1_col1, #T_7987f_row3_col1 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_7987f_row1_col2, #T_7987f_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_7987f_row1_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_7987f_row1_col5 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_7987f_row2_col0 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_7987f_row2_col1 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_7987f_row2_col2, #T_7987f_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_7987f_row2_col3 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_7987f_row2_col4 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_7987f_row2_col5 {
#   background-color: #95ca66;
#   color: #000000;
# }
# #T_7987f_row3_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_7987f_row3_col2 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_7987f_row3_col3 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_7987f_row3_col4 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_7987f_row3_col5 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_7987f_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_7987f_row5_col0, #T_7987f_row5_col1, #T_7987f_row5_col2, #T_7987f_row5_col3, #T_7987f_row5_col4, #T_7987f_row5_col5, #T_7987f_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7987f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_7987f_level0_col0" class="col_heading level0 col0" colspan="2">Human Resources</th>
#       <th id="T_7987f_level0_col2" class="col_heading level0 col2" colspan="2">Research & Development</th>
#       <th id="T_7987f_level0_col4" class="col_heading level0 col4" colspan="2">Sales</th>
#       <th id="T_7987f_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Attrition</th>
#       <th id="T_7987f_level1_col0" class="col_heading level1 col0" >No</th>
#       <th id="T_7987f_level1_col1" class="col_heading level1 col1" >Yes</th>
#       <th id="T_7987f_level1_col2" class="col_heading level1 col2" >No</th>
#       <th id="T_7987f_level1_col3" class="col_heading level1 col3" >Yes</th>
#       <th id="T_7987f_level1_col4" class="col_heading level1 col4" >No</th>
#       <th id="T_7987f_level1_col5" class="col_heading level1 col5" >Yes</th>
#       <th id="T_7987f_level1_col6" class="col_heading level1 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7987f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7987f_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_7987f_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7987f_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_7987f_row0_col3" class="data row0 col3" >19</td>
#       <td id="T_7987f_row0_col4" class="data row0 col4" >39</td>
#       <td id="T_7987f_row0_col5" class="data row0 col5" >11</td>
#       <td id="T_7987f_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_7987f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7987f_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_7987f_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_7987f_row1_col2" class="data row1 col2" >159</td>
#       <td id="T_7987f_row1_col3" class="data row1 col3" >23</td>
#       <td id="T_7987f_row1_col4" class="data row1 col4" >69</td>
#       <td id="T_7987f_row1_col5" class="data row1 col5" >18</td>
#       <td id="T_7987f_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_7987f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7987f_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_7987f_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_7987f_row2_col2" class="data row2 col2" >323</td>
#       <td id="T_7987f_row2_col3" class="data row2 col3" >56</td>
#       <td id="T_7987f_row2_col4" class="data row2 col4" >127</td>
#       <td id="T_7987f_row2_col5" class="data row2 col5" >39</td>
#       <td id="T_7987f_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_7987f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7987f_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_7987f_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_7987f_row3_col2" class="data row3 col2" >223</td>
#       <td id="T_7987f_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_7987f_row3_col4" class="data row3 col4" >105</td>
#       <td id="T_7987f_row3_col5" class="data row3 col5" >23</td>
#       <td id="T_7987f_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_7987f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7987f_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_7987f_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_7987f_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_7987f_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_7987f_row4_col4" class="data row4 col4" >14</td>
#       <td id="T_7987f_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_7987f_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_7987f_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_7987f_row5_col0" class="data row5 col0" >51</td>
#       <td id="T_7987f_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_7987f_row5_col2" class="data row5 col2" >828</td>
#       <td id="T_7987f_row5_col3" class="data row5 col3" >133</td>
#       <td id="T_7987f_row5_col4" class="data row5 col4" >354</td>
#       <td id="T_7987f_row5_col5" class="data row5 col5" >92</td>
#       <td id="T_7987f_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Employees distribution as per education field and level of education

# %%
data['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
labels ='Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources'
fig, ax= plt.subplots()
ax.pie(data['EducationField'].value_counts(),labels = labels, radius= 1, autopct= '%3.2f%%', explode=[0.1,0.1,0.125,0.15,0.15,0.175], shadow=True)
plt.show()

# %%
pd.crosstab([data.Education],[data.EducationField], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1b0c1_row0_col0, #T_1b0c1_row1_col0, #T_1b0c1_row4_col0, #T_1b0c1_row4_col1, #T_1b0c1_row4_col2, #T_1b0c1_row4_col3, #T_1b0c1_row4_col4, #T_1b0c1_row4_col5, #T_1b0c1_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1b0c1_row0_col1, #T_1b0c1_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_1b0c1_row0_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_1b0c1_row0_col3 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_1b0c1_row0_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_1b0c1_row0_col5 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_1b0c1_row1_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_1b0c1_row1_col2 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_1b0c1_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_1b0c1_row1_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_1b0c1_row1_col5 {
#   background-color: #daec66;
#   color: #000000;
# }
# #T_1b0c1_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_1b0c1_row2_col0 {
#   background-color: #70b866;
#   color: #f1f1f1;
# }
# #T_1b0c1_row2_col1 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_1b0c1_row2_col2 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_1b0c1_row2_col3 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_1b0c1_row2_col4, #T_1b0c1_row3_col2 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_1b0c1_row2_col5 {
#   background-color: #94ca66;
#   color: #000000;
# }
# #T_1b0c1_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_1b0c1_row3_col0 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_1b0c1_row3_col1 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_1b0c1_row3_col3 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_1b0c1_row3_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_1b0c1_row3_col5 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_1b0c1_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_1b0c1_row5_col0, #T_1b0c1_row5_col1, #T_1b0c1_row5_col2, #T_1b0c1_row5_col3, #T_1b0c1_row5_col4, #T_1b0c1_row5_col5, #T_1b0c1_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b0c1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th id="T_1b0c1_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_1b0c1_level0_col1" class="col_heading level0 col1" >Life Sciences</th>
#       <th id="T_1b0c1_level0_col2" class="col_heading level0 col2" >Marketing</th>
#       <th id="T_1b0c1_level0_col3" class="col_heading level0 col3" >Medical</th>
#       <th id="T_1b0c1_level0_col4" class="col_heading level0 col4" >Other</th>
#       <th id="T_1b0c1_level0_col5" class="col_heading level0 col5" >Technical Degree</th>
#       <th id="T_1b0c1_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b0c1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1b0c1_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_1b0c1_row0_col1" class="data row0 col1" >67</td>
#       <td id="T_1b0c1_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_1b0c1_row0_col3" class="data row0 col3" >63</td>
#       <td id="T_1b0c1_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_1b0c1_row0_col5" class="data row0 col5" >19</td>
#       <td id="T_1b0c1_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_1b0c1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1b0c1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1b0c1_row1_col1" class="data row1 col1" >116</td>
#       <td id="T_1b0c1_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_1b0c1_row1_col3" class="data row1 col3" >99</td>
#       <td id="T_1b0c1_row1_col4" class="data row1 col4" >19</td>
#       <td id="T_1b0c1_row1_col5" class="data row1 col5" >22</td>
#       <td id="T_1b0c1_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_1b0c1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1b0c1_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_1b0c1_row2_col1" class="data row2 col1" >233</td>
#       <td id="T_1b0c1_row2_col2" class="data row2 col2" >59</td>
#       <td id="T_1b0c1_row2_col3" class="data row2 col3" >183</td>
#       <td id="T_1b0c1_row2_col4" class="data row2 col4" >24</td>
#       <td id="T_1b0c1_row2_col5" class="data row2 col5" >57</td>
#       <td id="T_1b0c1_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_1b0c1_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1b0c1_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_1b0c1_row3_col1" class="data row3 col1" >173</td>
#       <td id="T_1b0c1_row3_col2" class="data row3 col2" >52</td>
#       <td id="T_1b0c1_row3_col3" class="data row3 col3" >104</td>
#       <td id="T_1b0c1_row3_col4" class="data row3 col4" >33</td>
#       <td id="T_1b0c1_row3_col5" class="data row3 col5" >31</td>
#       <td id="T_1b0c1_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_1b0c1_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_1b0c1_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_1b0c1_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_1b0c1_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_1b0c1_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_1b0c1_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_1b0c1_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_1b0c1_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_1b0c1_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_1b0c1_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_1b0c1_row5_col1" class="data row5 col1" >606</td>
#       <td id="T_1b0c1_row5_col2" class="data row5 col2" >159</td>
#       <td id="T_1b0c1_row5_col3" class="data row5 col3" >464</td>
#       <td id="T_1b0c1_row5_col4" class="data row5 col4" >82</td>
#       <td id="T_1b0c1_row5_col5" class="data row5 col5" >132</td>
#       <td id="T_1b0c1_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From the above observation we can say that,
#
# * 41.22 % Employees are from life science background followed by Medical Profession with 31.56
# * Most employees with technical degree are bachelors
# * Most of employees have master and doctors bolong to life science and medical domain.
# * 50 % employees in sales department having background of life science and medical.So it will be attrition rate in these employees.

# %% [markdown]
# ### Let's work on Job Role

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='JobRole',data = data)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Before going for Attrition by job role, First built matrix of department vs job role which will give us idea about number of employees of different job roles across department.

# %%
pd.crosstab([data.JobRole],[data.Department], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_bc390_row0_col0, #T_bc390_row0_col2, #T_bc390_row1_col1, #T_bc390_row1_col2, #T_bc390_row1_col3, #T_bc390_row2_col0, #T_bc390_row2_col2, #T_bc390_row4_col0, #T_bc390_row4_col2, #T_bc390_row5_col0, #T_bc390_row5_col2, #T_bc390_row6_col0, #T_bc390_row6_col2, #T_bc390_row7_col0, #T_bc390_row7_col1, #T_bc390_row8_col0, #T_bc390_row8_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bc390_row0_col1 {
#   background-color: #ddee66;
#   color: #000000;
# }
# #T_bc390_row0_col3, #T_bc390_row3_col1 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_bc390_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_bc390_row2_col1 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_bc390_row2_col3 {
#   background-color: #daec66;
#   color: #000000;
# }
# #T_bc390_row3_col0 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_bc390_row3_col2, #T_bc390_row5_col1 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_bc390_row3_col3 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_bc390_row4_col1 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_bc390_row4_col3 {
#   background-color: #eff766;
#   color: #000000;
# }
# #T_bc390_row5_col3, #T_bc390_row8_col3 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_bc390_row6_col1 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_bc390_row6_col3 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_bc390_row7_col2 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_bc390_row7_col3 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_bc390_row8_col2 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_bc390_row9_col0, #T_bc390_row9_col1, #T_bc390_row9_col2, #T_bc390_row9_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc390">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_bc390_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_bc390_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_bc390_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_bc390_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc390_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_bc390_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bc390_row0_col1" class="data row0 col1" >131</td>
#       <td id="T_bc390_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_bc390_row0_col3" class="data row0 col3" >131</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_bc390_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_bc390_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_bc390_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_bc390_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_bc390_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_bc390_row2_col1" class="data row2 col1" >259</td>
#       <td id="T_bc390_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_bc390_row2_col3" class="data row2 col3" >259</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_bc390_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_bc390_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_bc390_row3_col2" class="data row3 col2" >37</td>
#       <td id="T_bc390_row3_col3" class="data row3 col3" >102</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row4" class="row_heading level0 row4" >Manufacturing Director</th>
#       <td id="T_bc390_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_bc390_row4_col1" class="data row4 col1" >145</td>
#       <td id="T_bc390_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_bc390_row4_col3" class="data row4 col3" >145</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row5" class="row_heading level0 row5" >Research Director</th>
#       <td id="T_bc390_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_bc390_row5_col1" class="data row5 col1" >80</td>
#       <td id="T_bc390_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_bc390_row5_col3" class="data row5 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row6" class="row_heading level0 row6" >Research Scientist</th>
#       <td id="T_bc390_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_bc390_row6_col1" class="data row6 col1" >292</td>
#       <td id="T_bc390_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_bc390_row6_col3" class="data row6 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row7" class="row_heading level0 row7" >Sales Executive</th>
#       <td id="T_bc390_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_bc390_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_bc390_row7_col2" class="data row7 col2" >326</td>
#       <td id="T_bc390_row7_col3" class="data row7 col3" >326</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row8" class="row_heading level0 row8" >Sales Representative</th>
#       <td id="T_bc390_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_bc390_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_bc390_row8_col2" class="data row8 col2" >83</td>
#       <td id="T_bc390_row8_col3" class="data row8 col3" >83</td>
#     </tr>
#     <tr>
#       <th id="T_bc390_level0_row9" class="row_heading level0 row9" >All</th>
#       <td id="T_bc390_row9_col0" class="data row9 col0" >63</td>
#       <td id="T_bc390_row9_col1" class="data row9 col1" >961</td>
#       <td id="T_bc390_row9_col2" class="data row9 col2" >446</td>
#       <td id="T_bc390_row9_col3" class="data row9 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From the above observation we can say that,
# - There are 3 jobs in HR Department, maximum of which are sales Executive with 446 Total employees.
# - Human Resources department has 2 job role. Hr & Manager.

# %%
plt.figure(figsize=(12,10))
da = pd.crosstab(data['JobRole'],data['Attrition'])
da.div(da.sum(1).astype(float),axis = 0).plot(kind = 'bar', stacked = True, color = ['Blue','red'],figsize=(12,8))
plt.title("Attrition as per job role", fontsize = 20)
plt.xlabel("job role",fontsize = 15)
plt.show()

# %% [markdown]
# We all can definetly see Red signs for difference Managers & HR of Respective job role in above barplot.
# Bar plot showing % attrition across each job role, let's check absolute number matrix of attrition, again by using crosstab.

# %%
pd.crosstab([data.JobRole,data.Department],[data.Attrition], margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_18abd_row0_col0, #T_18abd_row6_col2 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_18abd_row0_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_18abd_row0_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_18abd_row1_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_18abd_row1_col1, #T_18abd_row7_col2, #T_18abd_row10_col2 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_18abd_row1_col2, #T_18abd_row4_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_18abd_row2_col0 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_18abd_row2_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_18abd_row2_col2 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_18abd_row3_col0, #T_18abd_row3_col1, #T_18abd_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_18abd_row4_col0, #T_18abd_row10_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_18abd_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_18abd_row5_col0 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_18abd_row5_col1, #T_18abd_row7_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_18abd_row5_col2 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_18abd_row6_col0 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_18abd_row6_col1 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_18abd_row7_col0 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_18abd_row8_col0, #T_18abd_row8_col2 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_18abd_row8_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_18abd_row9_col0 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_18abd_row9_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_18abd_row9_col2 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_18abd_row10_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_18abd_row11_col0, #T_18abd_row11_col1, #T_18abd_row11_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_18abd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_18abd_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_18abd_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_18abd_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18abd_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <th id="T_18abd_level1_row0" class="row_heading level1 row0" >Research & Development</th>
#       <td id="T_18abd_row0_col0" class="data row0 col0" >122</td>
#       <td id="T_18abd_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_18abd_row0_col2" class="data row0 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <th id="T_18abd_level1_row1" class="row_heading level1 row1" >Human Resources</th>
#       <td id="T_18abd_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_18abd_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_18abd_row1_col2" class="data row1 col2" >52</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <th id="T_18abd_level1_row2" class="row_heading level1 row2" >Research & Development</th>
#       <td id="T_18abd_row2_col0" class="data row2 col0" >197</td>
#       <td id="T_18abd_row2_col1" class="data row2 col1" >62</td>
#       <td id="T_18abd_row2_col2" class="data row2 col2" >259</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row3" class="row_heading level0 row3" rowspan="3">Manager</th>
#       <th id="T_18abd_level1_row3" class="row_heading level1 row3" >Human Resources</th>
#       <td id="T_18abd_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_18abd_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_18abd_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level1_row4" class="row_heading level1 row4" >Research & Development</th>
#       <td id="T_18abd_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_18abd_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_18abd_row4_col2" class="data row4 col2" >54</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level1_row5" class="row_heading level1 row5" >Sales</th>
#       <td id="T_18abd_row5_col0" class="data row5 col0" >35</td>
#       <td id="T_18abd_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_18abd_row5_col2" class="data row5 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row6" class="row_heading level0 row6" >Manufacturing Director</th>
#       <th id="T_18abd_level1_row6" class="row_heading level1 row6" >Research & Development</th>
#       <td id="T_18abd_row6_col0" class="data row6 col0" >135</td>
#       <td id="T_18abd_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_18abd_row6_col2" class="data row6 col2" >145</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row7" class="row_heading level0 row7" >Research Director</th>
#       <th id="T_18abd_level1_row7" class="row_heading level1 row7" >Research & Development</th>
#       <td id="T_18abd_row7_col0" class="data row7 col0" >78</td>
#       <td id="T_18abd_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_18abd_row7_col2" class="data row7 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row8" class="row_heading level0 row8" >Research Scientist</th>
#       <th id="T_18abd_level1_row8" class="row_heading level1 row8" >Research & Development</th>
#       <td id="T_18abd_row8_col0" class="data row8 col0" >245</td>
#       <td id="T_18abd_row8_col1" class="data row8 col1" >47</td>
#       <td id="T_18abd_row8_col2" class="data row8 col2" >292</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row9" class="row_heading level0 row9" >Sales Executive</th>
#       <th id="T_18abd_level1_row9" class="row_heading level1 row9" >Sales</th>
#       <td id="T_18abd_row9_col0" class="data row9 col0" >269</td>
#       <td id="T_18abd_row9_col1" class="data row9 col1" >57</td>
#       <td id="T_18abd_row9_col2" class="data row9 col2" >326</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row10" class="row_heading level0 row10" >Sales Representative</th>
#       <th id="T_18abd_level1_row10" class="row_heading level1 row10" >Sales</th>
#       <td id="T_18abd_row10_col0" class="data row10 col0" >50</td>
#       <td id="T_18abd_row10_col1" class="data row10 col1" >33</td>
#       <td id="T_18abd_row10_col2" class="data row10 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_18abd_level0_row11" class="row_heading level0 row11" >All</th>
#       <th id="T_18abd_level1_row11" class="row_heading level1 row11" ></th>
#       <td id="T_18abd_row11_col0" class="data row11 col0" >1233</td>
#       <td id="T_18abd_row11_col1" class="data row11 col1" >237</td>
#       <td id="T_18abd_row11_col2" class="data row11 col2" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Grouping Numeric Features
Numeric = ['Age','DailyRate','DistanceFromHome','EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel',
          'JobSatisfaction','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating',
          'RelationshipSatisfaction','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear',
          'WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %% [markdown]
# ### Boxplot for Numeric Variables

# %%
#Grouping Numeric Features
Numeric_int = ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate',
               'NumCompaniesWorked','PercentSalaryHike','TrainingTimesLastYear',
             'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager' ]

# %%
sns.set_palette('hsv')
plt.figure(figsize=(20,20), facecolor ='yellow')
plotnumber = 1

for i in Numeric_int:
    if plotnumber <=25:
        ax = plt.subplot(9,3,plotnumber)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize = 20)
        plt.xticks(rotation = 30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above observation we can say that,
# * Majority of people have spend 3 to 10 years in company.
# * Most of people staying in company upto 2 years after promotion.
# * Majority of people are trained 2-3 times inlast years.
# * Majority of people stay in same role for maximum 4 yrs.
# * Majority of Employees have salary hike from 10 to 15%.
#
# # Age V/S Attrition

# %%
plt.subplots(figsize=(12,6))
sns.countplot(x='Age',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set_palette('hsv')
plt.subplots(figsize=(18,8))
sns.countplot(x='Age', hue='Attrition',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# From the above observation we can say that,
# * The Attrition rate is minimum between the Age years of 34 and 35
# * The Attrition rate is maximum between the Age years of 29 and 31

# %%
plt.figure(figsize = (15,8))
sns.barplot(x='TotalWorkingYears', y='MonthlyIncome',data = data)
plt.xlabel("Total working years",fontsize = 20)
plt.ylabel("Monthly Income",fontsize = 20)
plt.title("Total Working Years V/S Monthly Income", fontsize = 20)
plt.show()

# %% [markdown]
# Monthly income is highest for the employees with 21 or more number of total working years.

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='MonthlyIncome', data = data)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.show()

# %% [markdown]
# The rate of Attrition is high when the employees did not got promoted since 1.8 years.
#
# ### Encoding Categorial Data

# %%
#using label encoder on target variables

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Attrition'] = le.fit_transform(data["Attrition"])
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
#Dropping unnecessary columns

data.drop(["EmployeeCount","EmployeeNumber","Over18","StandardHours"], axis =1, inplace = True)

# %%
data.shape
# Out:
# (1470, 31)

# %%
# oridinal Encoding for oridinal variables

from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
def ordinal_encoder(data, column):
    data[column] = oe.fit_transform(data[column])
    return data
oe_col = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
data = ordinal_encoder(data, oe_col)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1             2.0       1102         2.0                 1
# 1   49          0             1.0        279         1.0                 8
# 2   37          1             2.0       1373         1.0                 2
# 3   33          0             1.0       1392         1.0                 3
# 4   27          0             2.0        591         1.0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2             1.0                        2     0.0  ...
# 1          1             1.0                        3     1.0  ...
# 2          2             4.0                        4     1.0  ...
# 3          4             1.0                        4     0.0  ...
# 4          1             3.0                        1     1.0  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Outliers detection and removal

# %%
plt.figure(figsize=(25,30), facecolor='yellow')
plotnumber = 1
for column in Numeric:
    if plotnumber <=28:
        ax = plt.subplot(6,6, plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize = 12)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Features Contain Outliers
#
# "MonthlyIncome","NumCompaniesWorked","PerformanceRating","StockOptionLevel","TotalWorkingHours","TrainingTimesLastYear",
#
# "YearsAtCompany","YearsInCurrentRole","YearsSinceLastPromotion","YearsWithCurrManager","Attrition".

# %%
from scipy.stats import zscore
z = np.abs(zscore(data))
threshold = 3
df = data[(z<3).all(axis = 1)]
print("Shape of the dataframe before removing outliers: ",data.shape)
print("Shape of the dataframe after removing outliers: ",df.shape)
# Out:
# Shape of the dataframe before removing outliers:  (1470, 31)
# Shape of the dataframe after removing outliers:  (1387, 31)

# %%
print("Percentage Data Loss",((1470-1387)/1470)*100,'%')
# Out:
# Percentage Data Loss 5.646258503401361 %

# %% [markdown]
# ### Features Selection and Engineering

# %%
data.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
# Spliting data in target and dependent features

x = data.drop(['Attrition'], axis = 1)
y = data['Attrition']

# %% [markdown]
# ### Transforming skew data using power transform

# %%
from sklearn.preprocessing import power_transform
data = power_transform(x)
data = pd.DataFrame(data, columns=x.columns)
data.skew()
# Out:
# Age                        -0.007603
# BusinessTravel             -0.970506
# DailyRate                  -0.196160
# Department                  0.013801
# DistanceFromHome           -0.007468
# Education                  -0.099881
# EducationField             -0.008386
# EnvironmentSatisfaction    -0.205395
# Gender                     -0.408665
# HourlyRate                 -0.106461
# JobInvolvement             -0.020365
# JobLevel                    0.103624
# JobRole                    -0.319659
# JobSatisfaction            -0.212815
# MaritalStatus              -0.156911
# MonthlyIncome               0.032831
# MonthlyRate                -0.184087
# NumCompaniesWorked          0.014814
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.193634
# StockOptionLevel            0.087019
# TotalWorkingYears          -0.010653
# TrainingTimesLastYear       0.058058
# WorkLifeBalance            -0.012286
# YearsAtCompany             -0.008683
# YearsInCurrentRole         -0.060849
# YearsSinceLastPromotion     0.212129
# YearsWithCurrManager       -0.067565
# dtype: float64

# %% [markdown]
# From above Observation we can say
# - For Numeric features skewness is transform within permissible limit.
# - For ordinal features & categorial features skew parameter irrevalent.
#
# ## Corrleation

# %%
data.corr()
# Out:
#                                Age  BusinessTravel  DailyRate  Department  \
# Age                       1.000000        0.023122   0.008698   -0.031705
# BusinessTravel            0.023122        1.000000  -0.002284   -0.008546
# DailyRate                 0.008698       -0.002284   1.000000    0.009475
# Department               -0.031705       -0.008546   0.009475    1.000000
# DistanceFromHome         -0.020217       -0.004196  -0.006339    0.028267
# Education                 0.222197        0.002295  -0.015889    0.008091
# EducationField           -0.042503        0.033321   0.038007    0.083399
# EnvironmentSatisfaction   0.010458        0.006739   0.018745   -0.018705
# Gender                   -0.034937       -0.020448  -0.009390   -0.042226
# HourlyRate                0.024993        0.027346   0.024923   -0.003057
# JobInvolvement            0.026648        0.028043   0.039882   -0.025717
# JobLevel                  0.492901        0.005830   0.002658    0.175710
# JobRole                  -0.126484       -0.001069  -0.006542    0.663585
# JobSatisfaction          -0.005163       -0.035082   0.032726    0.022774
# MaritalStatus            -0.108030        0.015472  -0.071064    0.056654
# MonthlyIncome             0.498725        0.031281   0.013757    0.133925
# MonthlyRate               0.020052       -0.011337  -0.033383    0.024062
# NumCompaniesWorked        0.330170        0.033247   0.038445   -0.029246
# OverTime                  0.023349        0.004607   0.008809    0.007586
# PercentSalaryHike         0.003089       -0.022823   0.024132   -0.001491
# PerformanceRating         0.000396       -0.026814   0.000446   -0.023715
# RelationshipSatisfaction  0.049067       -0.039262   0.009514   -0.021470
# StockOptionLevel          0.074398       -0.008863   0.041513   -0.011815
# TotalWorkingYears         0.688330        0.032963   0.020035   -0.007675
# TrainingTimesLastYear    -0.017274        0.011046   0.001518    0.040729
# WorkLifeBalance          -0.019839       -0.013531  -0.040560    0.019835
# YearsAtCompany            0.296016       -0.013268  -0.012831    0.019416
# YearsInCurrentRole        0.214870       -0.023616   0.010738    0.051042
# YearsSinceLastPromotion   0.181112       -0.034572  -0.038267    0.019560
# YearsWithCurrManager      0.205007       -0.019191  -0.003915    0.025185
#
#                           DistanceFromHome  Education  EducationField  \
# Age                              -0.020217   0.222197       -0.042503
# BusinessTravel                   -0.004196   0.002295        0.033321
# DailyRate                        -0.006339  -0.015889        0.038007
# Department                        0.028267   0.008091        0.083399
# DistanceFromHome                  1.000000   0.018890        0.016314
# Education                         0.018890   1.000000       -0.040600
# EducationField                    0.016314  -0.040600        1.000000
# EnvironmentSatisfaction          -0.010807  -0.027374        0.038244
# Gender                            0.007120  -0.015405       -0.008876
# HourlyRate                        0.018471   0.017171       -0.019989
# JobInvolvement                    0.032466   0.042076       -0.006331
# JobLevel                          0.020035   0.117368       -0.033224
# JobRole                           0.009838   0.004749        0.047712
# JobSatisfaction                  -0.012649  -0.009120       -0.034546
# MaritalStatus                    -0.023468   0.004778        0.017318
# MonthlyIncome                    -0.002118   0.125997       -0.026699
# MonthlyRate                       0.038934  -0.025959       -0.029913
# NumCompaniesWorked               -0.006354   0.131599       -0.019100
# OverTime                          0.037156  -0.018418        0.004386
# PercentSalaryHike                 0.031207   0.000361       -0.002467
# PerformanceRating                 0.011620  -0.023231       -0.002094
# RelationshipSatisfaction          0.008565  -0.011414       -0.006867
# StockOptionLevel                  0.026372   0.015644       -0.015419
# TotalWorkingYears                -0.006758   0.168722       -0.013070
# TrainingTimesLastYear            -0.019278  -0.021986        0.054753
# WorkLifeBalance                  -0.026194   0.012489        0.042226
# YearsAtCompany                    0.006935   0.063270       -0.000861
# YearsInCurrentRole                0.014965   0.059071        0.001852
# YearsSinceLastPromotion          -0.001965   0.031791        0.014959
# YearsWithCurrManager              0.006663   0.057298        0.013809
#
#                           EnvironmentSatisfaction    Gender  HourlyRate  ...  \
# Age                                      0.010458 -0.034937    0.024993  ...
# BusinessTravel                           0.006739 -0.020448    0.027346  ...
# DailyRate                                0.018745 -0.009390    0.024923  ...
# Department                              -0.018705 -0.042226   -0.003057  ...
# DistanceFromHome                        -0.010807  0.007120    0.018471  ...
# Education                               -0.027374 -0.015405    0.017171  ...
# EducationField                           0.038244 -0.008876   -0.019989  ...
# EnvironmentSatisfaction                  1.000000  0.001118   -0.052050  ...
# Gender                                   0.001118  1.000000    0.000237  ...
# HourlyRate                              -0.052050  0.000237    1.000000  ...
# JobInvolvement                          -0.015587  0.020614    0.045037  ...
# JobLevel                                 0.000719 -0.049954   -0.033865  ...
# JobRole                                 -0.017504 -0.039548   -0.018402  ...
# JobSatisfaction                         -0.005079  0.034408   -0.070146  ...
# MaritalStatus                           -0.002846 -0.047206   -0.019006  ...
# MonthlyIncome                           -0.017045 -0.046229   -0.017254  ...
# MonthlyRate                              0.041251 -0.041844   -0.015633  ...
# NumCompaniesWorked                       0.006141 -0.041825    0.021841  ...
# OverTime                                 0.069043 -0.041924   -0.006755  ...
# PercentSalaryHike                       -0.030961  0.009383   -0.011802  ...
# PerformanceRating                       -0.029372 -0.013859   -0.002657  ...
# RelationshipSatisfaction                 0.006627  0.022709    0.001166  ...
# StockOptionLevel                         0.012090  0.011432    0.049036  ...
# TotalWorkingYears                       -0.015235 -0.044449   -0.007556  ...
# TrainingTimesLastYear                   -0.018413 -0.037641   -0.011174  ...
# WorkLifeBalance                          0.025734  0.000237   -0.009125  ...
# YearsAtCompany                           0.006821 -0.041930   -0.028621  ...
# YearsInCurrentRole                       0.016828 -0.038321   -0.029461  ...
# YearsSinceLastPromotion                  0.028181 -0.026019   -0.050841  ...
# YearsWithCurrManager                    -0.000664 -0.026981   -0.018600  ...
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.000396                  0.049067
# BusinessTravel                    -0.026814                 -0.039262
# DailyRate                          0.000446                  0.009514
# Department                        -0.023715                 -0.021470
# DistanceFromHome                   0.011620                  0.008565
# Education                         -0.023231                 -0.011414
# EducationField                    -0.002094                 -0.006867
# EnvironmentSatisfaction           -0.029372                  0.006627
# Gender                            -0.013859                  0.022709
# HourlyRate                        -0.002657                  0.001166
# JobInvolvement                    -0.027277                  0.035223
# JobLevel                          -0.019635                  0.011035
# JobRole                           -0.024695                 -0.017752
# JobSatisfaction                    0.004409                 -0.013506
# MaritalStatus                      0.005224                  0.024391
# MonthlyIncome                     -0.026039                  0.002090
# MonthlyRate                       -0.011683                 -0.003047
# NumCompaniesWorked                -0.005811                  0.045088
# OverTime                           0.004369                  0.048019
# PercentSalaryHike                  0.650607                 -0.036962
# PerformanceRating                  1.000000                 -0.032137
# RelationshipSatisfaction          -0.032137                  1.000000
# StockOptionLevel                   0.012762                 -0.056119
# TotalWorkingYears                  0.008306                  0.007309
# TrainingTimesLastYear             -0.016105                  0.000086
# WorkLifeBalance                    0.003307                  0.018812
# YearsAtCompany                     0.010261                  0.001633
# YearsInCurrentRole                 0.028137                 -0.014595
# YearsSinceLastPromotion           -0.006104                  0.032662
# YearsWithCurrManager               0.017947                  0.002185
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.074398           0.688330
# BusinessTravel                   -0.008863           0.032963
# DailyRate                         0.041513           0.020035
# Department                       -0.011815          -0.007675
# DistanceFromHome                  0.026372          -0.006758
# Education                         0.015644           0.168722
# EducationField                   -0.015419          -0.013070
# EnvironmentSatisfaction           0.012090          -0.015235
# Gender                            0.011432          -0.044449
# HourlyRate                        0.049036          -0.007556
# JobInvolvement                    0.032074           0.007772
# JobLevel                          0.049564           0.736058
# JobRole                          -0.030366          -0.149264
# JobSatisfaction                   0.010190          -0.020142
# MaritalStatus                    -0.741224          -0.095919
# MonthlyIncome                     0.050854           0.746077
# MonthlyRate                      -0.039115           0.008542
# NumCompaniesWorked                0.031528           0.297582
# OverTime                         -0.007004           0.005162
# PercentSalaryHike                 0.024267          -0.028876
# PerformanceRating                 0.012762           0.008306
# RelationshipSatisfaction         -0.056119           0.007309
# StockOptionLevel                  1.000000           0.056785
# TotalWorkingYears                 0.056785           1.000000
# TrainingTimesLastYear             0.005969          -0.023856
# WorkLifeBalance                  -0.011866           0.003008
# YearsAtCompany                    0.066191           0.611180
# YearsInCurrentRole                0.071144           0.491390
# YearsSinceLastPromotion           0.028244           0.343153
# YearsWithCurrManager              0.054407           0.490634
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.017274        -0.019839
# BusinessTravel                         0.011046        -0.013531
# DailyRate                              0.001518        -0.040560
# Department                             0.040729         0.019835
# DistanceFromHome                      -0.019278        -0.026194
# Education                             -0.021986         0.012489
# EducationField                         0.054753         0.042226
# EnvironmentSatisfaction               -0.018413         0.025734
# Gender                                -0.037641         0.000237
# HourlyRate                            -0.011174        -0.009125
# JobInvolvement                        -0.020683        -0.017115
# JobLevel                              -0.011793         0.043252
# JobRole                                0.002762         0.021489
# JobSatisfaction                       -0.010148        -0.020772
# MaritalStatus                          0.009848         0.016115
# MonthlyIncome                         -0.032653         0.032125
# MonthlyRate                           -0.004056         0.007394
# NumCompaniesWorked                    -0.055370         0.011494
# OverTime                              -0.074880        -0.030548
# PercentSalaryHike                     -0.008797        -0.006044
# PerformanceRating                     -0.016105         0.003307
# RelationshipSatisfaction               0.000086         0.018812
# StockOptionLevel                       0.005969        -0.011866
# TotalWorkingYears                     -0.023856         0.003008
# TrainingTimesLastYear                  1.000000         0.027004
# WorkLifeBalance                        0.027004         1.000000
# YearsAtCompany                        -0.005236         0.008294
# YearsInCurrentRole                    -0.009254         0.030028
# YearsSinceLastPromotion                0.008385         0.006686
# YearsWithCurrManager                  -0.012689        -0.005925
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.296016            0.214870
# BusinessTravel                 -0.013268           -0.023616
# DailyRate                      -0.012831            0.010738
# Department                      0.019416            0.051042
# DistanceFromHome                0.006935            0.014965
# Education                       0.063270            0.059071
# EducationField                 -0.000861            0.001852
# EnvironmentSatisfaction         0.006821            0.016828
# Gender                         -0.041930           -0.038321
# HourlyRate                     -0.028621           -0.029461
# JobInvolvement                  0.010027            0.018149
# JobLevel                        0.478875            0.383464
# JobRole                        -0.070222           -0.015588
# JobSatisfaction                 0.006424            0.000165
# MaritalStatus                  -0.079491           -0.063989
# MonthlyIncome                   0.487503            0.400622
# MonthlyRate                    -0.033939           -0.011063
# NumCompaniesWorked             -0.155734           -0.115426
# OverTime                       -0.029917           -0.035625
# PercentSalaryHike              -0.059348           -0.028215
# PerformanceRating               0.010261            0.028137
# RelationshipSatisfaction        0.001633           -0.014595
# StockOptionLevel                0.066191            0.071144
# TotalWorkingYears               0.611180            0.491390
# TrainingTimesLastYear          -0.005236           -0.009254
# WorkLifeBalance                 0.008294            0.030028
# YearsAtCompany                  1.000000            0.838341
# YearsInCurrentRole              0.838341            1.000000
# YearsSinceLastPromotion         0.537925            0.525095
# YearsWithCurrManager            0.830526            0.732958
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.181112              0.205007
# BusinessTravel                          -0.034572             -0.019191
# DailyRate                               -0.038267             -0.003915
# Department                               0.019560              0.025185
# DistanceFromHome                        -0.001965              0.006663
# Education                                0.031791              0.057298
# EducationField                           0.014959              0.013809
# EnvironmentSatisfaction                  0.028181             -0.000664
# Gender                                  -0.026019             -0.026981
# HourlyRate                              -0.050841             -0.018600
# JobInvolvement                          -0.012434              0.048002
# JobLevel                                 0.269877              0.366696
# JobRole                                 -0.025375             -0.034877
# JobSatisfaction                          0.005061             -0.018406
# MaritalStatus                           -0.015153             -0.047478
# MonthlyIncome                            0.278215              0.371462
# MonthlyRate                             -0.014987             -0.038723
# NumCompaniesWorked                      -0.067230             -0.134886
# OverTime                                -0.017443             -0.040674
# PercentSalaryHike                       -0.053643             -0.029960
# PerformanceRating                       -0.006104              0.017947
# RelationshipSatisfaction                 0.032662              0.002185
# StockOptionLevel                         0.028244              0.054407
# TotalWorkingYears                        0.343153              0.490634
# TrainingTimesLastYear                    0.008385             -0.012689
# WorkLifeBalance                          0.006686             -0.005925
# YearsAtCompany                           0.537925              0.830526
# YearsInCurrentRole                       0.525095              0.732958
# YearsSinceLastPromotion                  1.000000              0.488768
# YearsWithCurrManager                     0.488768              1.000000
#
# [30 rows x 30 columns]

# %%
a = np.triu(data.corr())
plt.figure(figsize=(25,15))
sns.heatmap(data.corr(),vmin=-1,vmax = 1, annot = True, square = True, fmt='0.3f',
           annot_kws={'size':10},cmap='gist_stern',mask=a)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(18,6))
df.corr()['Attrition'].drop(['Attrition']).plot(kind = 'bar', color = 'c')
plt.xlabel('Features',fontsize = 15)
plt.ylabel('Attrition',fontsize=15)
plt.title('Correlation of features with target variables Attrition',fontsize=18)
plt.show()

# %% [markdown]
# From the above observation
# * Age,JobLevel,MonthlyIncome is highly positively correlated with TotalWorkingYears.
# * JobLevel is highly Positively correlated with the MonthlyIncome.
# * PercentageSalaryHike is highly positively correlated with the column PerformanceRating.
#
# ### Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
vif['Features']=data.columns
vif
# Out:
#          VIF                  Features
# 0   2.103475                       Age
# 1   1.015631            BusinessTravel
# 2   1.022320                 DailyRate
# 3   2.027022                Department
# 4   1.014061          DistanceFromHome
# 5   1.068566                 Education
# 6   1.027363            EducationField
# 7   1.021627   EnvironmentSatisfaction
# 8   1.020116                    Gender
# 9   1.022891                HourlyRate
# 10  1.020342            JobInvolvement
# 11  6.745928                  JobLevel
# 12  1.922650                   JobRole
# 13  1.020705           JobSatisfaction
# 14  2.299559             MaritalStatus
# 15  6.663767             MonthlyIncome
# 16  1.019831               MonthlyRate
# 17  1.418545        NumCompaniesWorked
# 18  1.028870                  OverTime
# 19  1.017518         PercentSalaryHike
# 20  1.757763         PerformanceRating
# 21  1.022138  RelationshipSatisfaction
# 22  2.270037          StockOptionLevel
# 23  4.825803         TotalWorkingYears
# 24  1.022267     TrainingTimesLastYear
# 25  1.016488           WorkLifeBalance
# 26  6.632607            YearsAtCompany
# 27  3.590572        YearsInCurrentRole
# 28  1.471580   YearsSinceLastPromotion
# 29  3.365339      YearsWithCurrManager

# %% [markdown]
# We can see that multicollinearity is when permissible limit of 10.
# ### Balacing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# oversampling using SMOTE Techniques

oversample = SMOTE()
x,y = oversample.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %% [markdown]
# ### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scale = scaler.fit_transform(x)

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
# plot the graph to find the principal components
x_pca = pca.fit_transform(x_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of components')
plt.ylabel('Variance%')
plt.title("Explained variance ratio")
plt.grid()

# %%
pca_new = PCA(n_components=21)
x_new = pca_new.fit_transform(x_scale)

# %%
pri_x = pd.DataFrame(x_new, columns=np.arange(21))

# %% [markdown]
# As the graph, we can see that 21 pricipal components attributes for 90% of variables in the data. We shall pick the first 21 components for our prediction.
#
# ### Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(pri_x,y,test_size=.33, random_state=42)
print('Training feature matrix size:', x_train.shape)
print('Training target vector :',y_train.shape)
print('Test feature matrix size :',x_test.shape)
print('Test target vector size :', y_test.shape)
# Out:
# Training feature matrix size: (1652, 21)
# Training target vector : (1652,)
# Test feature matrix size : (814, 21)
# Test target vector size : (814,)

# %% [markdown]
# ### Finding Best random rate

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
maxAccu=0
maxRs=0
for i in range (1,250):
    x_train,x_test,y_train,y_test= train_test_split(pri_x,y,test_size = 0.33, random_state=i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu, 'on Random_state',maxRS)
# Out:
# Best accuracy is 0.8685503685503686 on Random_state 63

# %% [markdown]
# ### Logistic Regression

# %%
x_train,x_test,y_train,y_test = train_test_split(pri_x,y,test_size=.33,random_state=242)
lrr = LogisticRegression()
lrr.fit(x_train,y_train)
y_pred = lrr.predict(x_test)
print("Logistic Regression Evaluation")
print('\n')
print("Accuracy Score Of Logistic Regression : ",accuracy_score(y_test,y_pred))
print("Confusion Matrix Of Logistic Regression : ",confusion_matrix(y_test,y_pred))
print("Classification Report Of Logistic Regression : ", classification_report(y_test,y_pred))
# Out:
# Logistic Regression Evaluation
#
#
# Accuracy Score Of Logistic Regression :  0.8194103194103194
# Confusion Matrix Of Logistic Regression :  [[306  89]
#  [ 58 361]]
# Classification Report Of Logistic Regression :                precision    recall  f1-score   support
#
#            0       0.84      0.77      0.81       395
#            1       0.80      0.86      0.83       419
#
#     accuracy                           0.82       814
#    macro avg       0.82      0.82      0.82       814
# weighted avg       0.82      0.82      0.82       814

# %% [markdown]
# ### Cros Validation Score

# %%
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(lrr, x,y,cv=5)
print("Cross Validation Score",lrr)
print("CVS Score : ", cv_score)
print("Mean CVS Score : ", cv_score.mean())
print("Std Deviation : ",cv_score.std())
# Out:
# Cross Validation Score LogisticRegression()
# CVS Score :  [0.65587045 0.72413793 0.67545639 0.69371197 0.70385396]
# Mean CVS Score :  0.6906061377503675
# Std Deviation :  0.02343337454069585

# %% [markdown]
# ### GaussianNB

# %%
g = GaussianNB()
g.fit(x_train,y_train)
y_pred = g.predict(x_test)
print("GaussainNB Classifier")
print('\n')
print("Accuracy Score Of GaussianNB Classifier : ",accuracy_score(y_test,y_pred))
print("Confusion Matrix Of GaussianNB Classifier Classifier : ",confusion_matrix(y_test,y_pred))
print("Classification Report Of GaussianNB Classifier Classifier : ", classification_report(y_test,y_pred))
# Out:
# GaussainNB Classifier
#
#
# Accuracy Score Of GaussianNB Classifier :  0.8108108108108109
# Confusion Matrix Of GaussianNB Classifier Classifier :  [[320  75]
#  [ 79 340]]
# Classification Report Of GaussianNB Classifier Classifier :                precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       395
#            1       0.82      0.81      0.82       419
#
#     accuracy                           0.81       814
#    macro avg       0.81      0.81      0.81       814
# weighted avg       0.81      0.81      0.81       814

# %% [markdown]
# ### Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(lrr, x,y,cv=5)
print("Cross Validation Score",lrr)
print("CVS Score : ", cv_score)
print("Mean CVS Score : ", cv_score.mean())
print("Std Deviation : ",cv_score.std())
# Out:
# Cross Validation Score LogisticRegression()
# CVS Score :  [0.65587045 0.72413793 0.67545639 0.69371197 0.70385396]
# Mean CVS Score :  0.6906061377503675
# Std Deviation :  0.02343337454069585

# %% [markdown]
# ### Applying other classification algorithm

# %%
models =[
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    BaggingClassifier()]

for m in models:
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' + '\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :' + '\033[0m\n',accuracy_score(y_test,y_pred))
    print('\n')
    print('\033[1m'+'Confusion Matrix' + '\033[0m \n',confusion_matrix(y_test,y_pred))
    print('\n')
    print('\033[1m'+'Classification Report' + '\033[0m \n',classification_report(y_test,y_pred))
    print('\n')
    print('===================================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8759213759213759
#
#
# Confusion Matrix
#  [[339  56]
#  [ 45 374]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       395
#            1       0.87      0.89      0.88       419
#
#     accuracy                           0.88       814
#    macro avg       0.88      0.88      0.88       814
# weighted avg       0.88      0.88      0.88       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.7923832923832924
#
#
# Confusion Matrix
#  [[307  88]
#  [ 81 338]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       395
#            1       0.79      0.81      0.80       419
#
#     accuracy                           0.79       814
#    macro avg       0.79      0.79      0.79       814
# weighted avg       0.79      0.79      0.79       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier() is
#
#
# Accuracy Score :
#  0.8390663390663391
#
#
# Confusion Matrix
#  [[271 124]
#  [  7 412]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81       395
#            1       0.77      0.98      0.86       419
#
#     accuracy                           0.84       814
#    macro avg       0.87      0.83      0.83       814
# weighted avg       0.87      0.84      0.83       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8845208845208845
#
#
# Confusion Matrix
#  [[354  41]
#  [ 53 366]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       395
#            1       0.90      0.87      0.89       419
#
#     accuracy                           0.88       814
#    macro avg       0.88      0.88      0.88       814
# weighted avg       0.88      0.88      0.88       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix AdaBoostClassifier() is
#
#
# Accuracy Score :
#  0.8366093366093366
#
#
# Confusion Matrix
#  [[325  70]
#  [ 63 356]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       395
#            1       0.84      0.85      0.84       419
#
#     accuracy                           0.84       814
#    macro avg       0.84      0.84      0.84       814
# weighted avg       0.84      0.84      0.84       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix GradientBoostingClassifier() is
#
#
# Accuracy Score :
#  0.8636363636363636
#
#
# Confusion Matrix
#  [[337  58]
#  [ 53 366]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       395
#            1       0.86      0.87      0.87       419
#
#     accuracy                           0.86       814
#    macro avg       0.86      0.86      0.86       814
# weighted avg       0.86      0.86      0.86       814
#
#
#
# ===================================================================================================================
# Classification ML Algorithm Evaluation Matrix BaggingClassifier() is
#
#
# Accuracy Score :
#  0.8562653562653563
#
#
# Confusion Matrix
#  [[343  52]
#  [ 65 354]]
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       395
#            1       0.87      0.84      0.86       419
#
#     accuracy                           0.86       814
#    macro avg       0.86      0.86      0.86       814
# weighted avg       0.86      0.86      0.86       814
#
#
#
# ===================================================================================================================

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
model =[
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(n_neighbors=12),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    BaggingClassifier()]
for c in model:
    score = cross_val_score(c,x,y, cv=5)
    print('\n')
    print('\033[1m'+'Cross Validation Score',c,'is' + '\033[0m')
    print("Score",score)
    print("Mean Score :",score.mean())
    print("Std Deviation", score.std())
    print('\n')
    print('=====================================================================================================================')
# Out:
# Cross Validation Score SVC() is
# Score [0.59311741 0.64908722 0.60243408 0.61257606 0.59634888]
# Mean Score : 0.610712731274277
# Std Deviation 0.020300369766677723
#
#
# =====================================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() is
# Score [0.66801619 0.89452333 0.90263692 0.88438134 0.87626775]
# Mean Score : 0.8451651049921575
# Std Deviation 0.08902389248240676
#
#
# =====================================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=12) is
# Score [0.70647773 0.73427992 0.73630832 0.7484787  0.73225152]
# Mean Score : 0.7315592382422743
# Std Deviation 0.013753437868624775
#
#
# =====================================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() is
# Score [0.69433198 0.98377282 0.96957404 0.96146045 0.97971602]
# Mean Score : 0.9177710620755353
# Std Deviation 0.11199173404973468
#
#
# =====================================================================================================================
#
#
# Cross Validation Score AdaBoostClassifier() is
# Score [0.5951417  0.95334686 0.93711968 0.9148073  0.95537525]
# Mean Score : 0.8711581575251908
# Std Deviation 0.1387722996132398
#
#
# =====================================================================================================================
#
#
# Cross Validation Score GradientBoostingClassifier() is
# Score [0.57894737 0.97565923 0.95740365 0.93711968 0.97768763]
# Mean Score : 0.8853635101953667
# Std Deviation 0.15390672101019479
#
#
# =====================================================================================================================
#
#
# Cross Validation Score BaggingClassifier() is
# Score [0.65991903 0.95131846 0.94726166 0.94320487 0.95537525]
# Mean Score : 0.8914158543495578
# Std Deviation 0.11581948324810148
#
#
# =====================================================================================================================

# %% [markdown]
# ### Hyper Parameter Tunning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = [{'n_estimators':[5,10,15,25,50,100],
         'criterion':['gini','entropy'],
         'max_depth':[5,10,20,40,50,None],
         'max_features':['auto','log2'],
          'bootstrap':[True]}]

# %%
gc = GridSearchCV(RandomForestClassifier(),param,cv = 5, n_jobs = -1,verbose=5)
gc.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid=[{'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                           'max_depth': [5, 10, 20, 40, 50, None],
#                           'max_features': ['auto', 'log2'],
#                           'n_estimators': [5, 10, 15, 25, 50, 100]}],
#              verbose=5)

# %%
gc.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 50,
#  'max_features': 'auto',
#  'n_estimators': 100}

# %% [markdown]
# ### Final Model

# %%
final = RandomForestClassifier(bootstrap = True ,criterion= 'gini', max_depth = 50 , max_features = 'log2', n_estimators = 100)
final.fit(x_train,y_train)
y_pred = final.predict(x_test)
print(" Final Random Forest Classifier Evaluation")
print('\n')
print("Accuracy Score Of Random Forest Classifier : ",accuracy_score(y_test,y_pred))
# Out:
#  Final Random Forest Classifier Evaluation
#
#
# Accuracy Score Of Random Forest Classifier :  0.8734643734643734

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

y_pred_prob = final.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr, tpr, label='Random Forest Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
auc_score = roc_auc_score(y_test,final.predict(x_test))
print("AUC SCORE", auc_score)
# Out:
# AUC SCORE 0.8740430802694782

# %% [markdown]
# ### Saving Model

# %%
import joblib
joblib.dump(final,"HR_ANALYTICS")
# Out:
# ['HR_ANALYTICS']
